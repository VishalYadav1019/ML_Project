# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a=np.array([1,2,3,5,5,7,4])
b=np.array([1,2,3,4,5,6,7])
plt.plot(a,b)

# %%
plt.figure(figsize=(10,3))
plt.plot(a,color="red",label="A")
plt.plot(b,color="blue",label="B")
plt.legend()

# %%
y = np.array([35, 25, 25, 15])
ab = ["Apples", "Bananas", "Cherries", "Dates"]
me = [0, 0.3, 0.3,0.2 ]

plt.pie(y, labels = ab, explode = me)
plt.show()

# %%
c=sns.get_dataset_names()
c
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x="pclass",y="age", data=df)
plt.show()
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot([0,1,2,3,4,5,6],hist=True)
plt.show()
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_7424\2208051087.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5,6],hist=True)
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.relplot(x="pclass",y="age", data=df)
plt.show()

# %%
n=df["age"].mean()
n
# Out:
# 29.69911764705882

# %%
sns.histplot(x="age", data=df, bins=[i for i in range(0,81,10)])
plt.plot([n for i in  range(0,300)],[i for i in range(0,300)],c="red")
plt.show()
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
a=np.array([1,2,3,12,5])
b=np.array([3,4,6,2,7])

plt.subplot(1,2,1)
plt.plot(a,b)



v=np.array([5,6,8,7,8])
k=np.array([8,7,4,24,2])

plt.subplot(1,2,2)
plt.plot(v,k)

# %%
a=np.array([1,2,3,12,5])
b=np.array([3,4,6,2,7])

plt.subplot(1,3,1)
plt.bar(a,b)
plt.legend(a)



v=np.array([5,6,8,7,8])
k=np.array([8,7,4,2,2])

plt.subplot(1,3,2)
plt.bar(v,k)
plt.legend(v)

r=np.array([1,2,3,4,5,6])
p=np.array([1,2,3,4,5,6])

plt.subplot(1,3,3)
plt.bar(r,p)
plt.legend(r)
plt.show()

# %%
a=np.array([1,2,3,12,5])
b=np.array([3,4,6,2,7])

plt.subplot(3,1,1)
plt.bar(a,b)
plt.legend(a)



v=np.array([5,6,8,7,8])
k=np.array([8,7,4,2,2])

plt.subplot(3,1,2)
plt.bar(v,k)
plt.legend(v)

r=np.array([1,2,3,4,5,6])
p=np.array([1,2,3,4,5,6])

plt.subplot(3,1,3)
plt.bar(r,p)
plt.legend(r)

# %%
sect_A=np.array([67,65,96,45,36,74])
sect_B=np.array([78,63,96,85,67,88])
no=([1,2,3,4,5,6])
mean_A=np.mean(sect_A)
print("mean_A =",mean_A)
mean_B=np.mean(sect_B)
print("mean_B =",mean_B)
# Out:
# mean_A = 63.833333333333336
# mean_B = 79.5

# %%
plt.figure(figsize=(10,3))
plt.bar(sect_A,no,color="red",label="sect A")
plt.bar(sect_B,no,color="blue",label="sect B")
plt.plot([63.833,63.833,63.833,63.833,63.833,63.833],no,c="black",label="Mean A")
plt.plot([79.5,79.5,79.5,79.5,79.5,79.5],no,c="skyblue",label="Mean B")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.plot(sect_A,no,color="red",label="sect A")
plt.plot(sect_B,no,color="blue",label="sect B")
plt.plot([63.833,63.833,63.833,63.833,63.833,63.833],no,c="black",label="Mean A")
plt.plot([79.5,79.5,79.5,79.5,79.5,79.5],no,c="skyblue",label="Mean B")
plt.legend()
plt.show()
